# %%
# !pip install autoscraper

# %%
from autoscraper import AutoScraper

# %%
amazon_url = "https://www.nobroker.in/property/sale/pune/Narayan%20Peth/?searchParam=W3sibGF0IjoxOC41MTU0NzQxLCJsb24iOjczLjg1MDA3MTcsInBsYWNlSWQiOiJDaElKNDRaQXduREF3anNSNENsWWQ2b0xKX1UiLCJwbGFjZU5hbWUiOiJOYXJheWFuIFBldGgiLCJzaG93TWFwIjpmYWxzZX1d&propType=AP"
wanted_list =["600 sqft","₹65 Lacs","1 BHK"]

# %%
scraper = AutoScraper()
result = scraper.build(amazon_url,wanted_list)
print(result)
# Out:
# ['780 sqft', '₹45,851/Month', '₹80 Lacs', '600 sqft', '₹34,388/Month', '₹60 Lacs', '₹37,254/Month', '₹65 Lacs', '620 sqft', '₹25,791/Month', '₹45 Lacs', '1,400 sqft', '₹63,045/Month', '₹1.1 Crores', '730 sqft', '391 sqft', '660 sqft', '₹47,284/Month', '₹82.5 Lacs', '1,037 sqft', '₹45,278/Month', '₹79 Lacs', '619 sqft', '₹44,705/Month', '₹78 Lacs', '520 sqft', '530 sqft', '700 sqft', '₹42,985/Month', '₹75 Lacs', '2,000 sqft', '₹2.01 Lacs/Month', '₹3.5 Crores', '950 sqft', '597 sqft', '₹48,717/Month', '₹85 Lacs', '350 sqft', '₹20,060/Month', '₹35 Lacs', '810 sqft', '₹57,314/Month', '₹1 Crore', '885 sqft', '725 sqft', '₹32,669/Month', '₹57 Lacs', '550 sqft', '553 sqft', '₹31,522/Month', '₹55 Lacs', '740 sqft', '1,100 sqft', '₹85,971/Month', '₹1.5 Crores', '2 BHK', '2', 'Bike', '1 BHK', '1', 'None', '3 BHK', 'Bike and Car', '1 RK', 'Car', '4 BHK', '1 to 3']

# %%
scraper.get_result_similar(amazon_url,grouped=True)
# Out:
# {'rule_qld8': ['780 sqft',
#   '₹45,851/Month',
#   '₹80 Lacs',
#   '600 sqft',
#   '₹34,388/Month',
#   '₹60 Lacs',
#   '600 sqft',
#   '₹37,254/Month',
#   '₹65 Lacs',
#   '620 sqft',
#   '₹25,791/Month',
#   '₹45 Lacs',
#   '1,400 sqft',
#   '₹63,045/Month',
#   '₹1.1 Crores',
#   '730 sqft',
#   '₹45,851/Month',
#   '₹80 Lacs',
#   '391 sqft',
#   '₹25,791/Month',
#   '₹45 Lacs',
#   '660 sqft',
#   '₹47,284/Month',
#   '₹82.5 Lacs',
#   '1,037 sqft',
#   '₹45,278/Month',
#   '₹79 Lacs',
#   '619 sqft',
#   '₹44,705/Month',
#   '₹78 Lacs',
#   '520 sqft',
#   '₹37,254/Month',
#   '₹65 Lacs',
#   '530 sqft',
#   '₹34,388/Month',
#   '₹60 Lacs',
#   '700 sqft',
#   '₹42,985/Month',
#   '₹75 Lacs',
#   '2,000 sqft',
#   '₹2.01 Lacs/Month',
#   '₹3.5 Crores',
#   '950 sqft',
#   '₹45,851/Month',
#   '₹80 Lacs',
#   '597 sqft',
#   '₹48,717/Month',
#   '₹85 Lacs',
#   '350 sqft',
#   '₹20,060/Month',
#   '₹35 Lacs',
#   '810 sqft',
#   '₹57,314/Month',
#   '₹1 Crore',
#   '600 sqft',
# ...

# %% [markdown]
# rule_za0y:SQrft details
# rule_w3sn:price
# rule_gbxl:bhks

# %%
scraper.set_rule_aliases({"rule_qld8":"SQrft details","rule_hifz":"bhks"})
scraper.keep_rules(["rule_qld8","rule_hifz"])
scraper.save("Amazon-scearch")

# %%
results = scraper.get_result_similar("https://www.nobroker.in/property/sale/pune/Narayan%20Peth/?searchParam=W3sibGF0IjoxOC41MTU0NzQxLCJsb24iOjczLjg1MDA3MTcsInBsYWNlSWQiOiJDaElKNDRaQXduREF3anNSNENsWWQ2b0xKX1UiLCJwbGFjZU5hbWUiOiJOYXJheWFuIFBldGgiLCJzaG93TWFwIjpmYWxzZX1d&propType=AP",group_by_alias=True)

# %%
results["SQrft details"]
# Out:
# ['780 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '600 sqft',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '600 sqft',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '620 sqft',
#  '₹25,791/Month',
#  '₹45 Lacs',
#  '1,400 sqft',
#  '₹63,045/Month',
#  '₹1.1 Crores',
#  '730 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '391 sqft',
#  '₹25,791/Month',
#  '₹45 Lacs',
#  '660 sqft',
#  '₹47,284/Month',
#  '₹82.5 Lacs',
#  '1,037 sqft',
#  '₹45,278/Month',
#  '₹79 Lacs',
#  '619 sqft',
#  '₹44,705/Month',
#  '₹78 Lacs',
#  '520 sqft',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '530 sqft',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '700 sqft',
#  '₹42,985/Month',
#  '₹75 Lacs',
#  '2,000 sqft',
#  '₹2.01 Lacs/Month',
#  '₹3.5 Crores',
#  '950 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '597 sqft',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '350 sqft',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '810 sqft',
#  '₹57,314/Month',
#  '₹1 Crore',
#  '600 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '885 sqft',
# ...

# %%
results["bhks"]
# Out:
# ['2 BHK',
#  '2',
#  'Bike',
#  '1 BHK',
#  '1',
#  'Bike',
#  '1 BHK',
#  '1',
#  'None',
#  '1 BHK',
#  '1',
#  'Bike',
#  '3 BHK',
#  '2',
#  'Bike',
#  '2 BHK',
#  '1',
#  'Bike and Car',
#  '1 RK',
#  '1',
#  'Bike',
#  '1 BHK',
#  '1',
#  'Bike',
#  '2 BHK',
#  '1',
#  'Bike',
#  '1 BHK',
#  '1',
#  'Car',
#  '1 BHK',
#  '1',
#  'None',
#  '1 BHK',
#  '1',
#  'Bike',
#  '2 BHK',
#  '1',
#  'Car',
#  '4 BHK',
#  '2',
#  'Bike and Car',
#  '2 BHK',
#  '1',
#  'Bike',
#  '1 BHK',
#  '1',
#  'Bike',
#  '1 BHK',
#  '1',
#  'Bike',
#  '2 BHK',
#  '2',
#  'Bike and Car',
#  '1 BHK',
#  '1',
#  'Bike',
#  '3 BHK',
#  '2',
#  'Bike',
#  '1 BHK',
#  '2',
#  'Bike',
#  '1 BHK',
#  '1',
#  'Bike and Car',
#  '1 BHK',
#  '1',
#  'Bike',
#  '2 BHK',
#  '1',
#  'Bike and Car',
#  '2 BHK',
#  '2',
#  'Bike and Car']

# %%
results["SQrft details"]
# Out:
# ['780 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '600 sqft',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '600 sqft',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '620 sqft',
#  '₹25,791/Month',
#  '₹45 Lacs',
#  '1,400 sqft',
#  '₹63,045/Month',
#  '₹1.1 Crores',
#  '730 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '391 sqft',
#  '₹25,791/Month',
#  '₹45 Lacs',
#  '660 sqft',
#  '₹47,284/Month',
#  '₹82.5 Lacs',
#  '1,037 sqft',
#  '₹45,278/Month',
#  '₹79 Lacs',
#  '619 sqft',
#  '₹44,705/Month',
#  '₹78 Lacs',
#  '520 sqft',
#  '₹37,254/Month',
#  '₹65 Lacs',
#  '530 sqft',
#  '₹34,388/Month',
#  '₹60 Lacs',
#  '700 sqft',
#  '₹42,985/Month',
#  '₹75 Lacs',
#  '2,000 sqft',
#  '₹2.01 Lacs/Month',
#  '₹3.5 Crores',
#  '950 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '597 sqft',
#  '₹48,717/Month',
#  '₹85 Lacs',
#  '350 sqft',
#  '₹20,060/Month',
#  '₹35 Lacs',
#  '810 sqft',
#  '₹57,314/Month',
#  '₹1 Crore',
#  '600 sqft',
#  '₹45,851/Month',
#  '₹80 Lacs',
#  '885 sqft',
# ...

# %%
import pandas as pd

# %%
dss= pd.DataFrame((results["SQrft details"]))
dss
# Out:
#                 0
# 0        780 sqft
# 1   ₹45,851/Month
# 2        ₹80 Lacs
# 3        600 sqft
# 4   ₹34,388/Month
# ..            ...
# 70  ₹48,717/Month
# 71       ₹85 Lacs
# 72     1,100 sqft
# 73  ₹85,971/Month
# 74    ₹1.5 Crores
#
# [75 rows x 1 columns]

# %%
db = pd.DataFrame((results["bhks"]))
db
# Out:
#                0
# 0          2 BHK
# 1              2
# 2           Bike
# 3          1 BHK
# 4              1
# ..           ...
# 70             1
# 71  Bike and Car
# 72         2 BHK
# 73             2
# 74  Bike and Car
#
# [75 rows x 1 columns]

# %%
#dp1=dp.rename({0:"price(lacs)"},axis=1)
#dp1

# %%
dss=dss.rename({0:"Sqrft_details"},axis=1)
dss
# Out:
#     Sqrft_details
# 0        780 sqft
# 1   ₹45,851/Month
# 2        ₹80 Lacs
# 3        600 sqft
# 4   ₹34,388/Month
# ..            ...
# 70  ₹48,717/Month
# 71       ₹85 Lacs
# 72     1,100 sqft
# 73  ₹85,971/Month
# 74    ₹1.5 Crores
#
# [75 rows x 1 columns]

# %%
db=db.rename({0:"BHK"},axis=1)
db
# Out:
#              BHK
# 0          2 BHK
# 1              2
# 2           Bike
# 3          1 BHK
# 4              1
# ..           ...
# 70             1
# 71  Bike and Car
# 72         2 BHK
# 73             2
# 74  Bike and Car
#
# [75 rows x 1 columns]

# %%
db[["BHK"]]
# Out:
#              BHK
# 0          2 BHK
# 1              2
# 2           Bike
# 3          1 BHK
# 4              1
# ..           ...
# 70             1
# 71  Bike and Car
# 72         2 BHK
# 73             2
# 74  Bike and Car
#
# [75 rows x 1 columns]

# %%
ds=dss.loc[dss['Sqrft_details'].str.contains('sqft')]
ds
# Out:
#    Sqrft_details
# 0       780 sqft
# 3       600 sqft
# 6       600 sqft
# 9       620 sqft
# 12    1,400 sqft
# 15      730 sqft
# 18      391 sqft
# 21      660 sqft
# 24    1,037 sqft
# 27      619 sqft
# 30      520 sqft
# 33      530 sqft
# 36      700 sqft
# 39    2,000 sqft
# 42      950 sqft
# 45      597 sqft
# 48      350 sqft
# 51      810 sqft
# 54      600 sqft
# 57      885 sqft
# 60      725 sqft
# 63      550 sqft
# 66      553 sqft
# 69      740 sqft
# 72    1,100 sqft

# %%
dp=dss.loc[dss['Sqrft_details'].str.contains('Lacs')]
dp=dp.rename({"Sqrft_details":"price(Lacs)"},axis=1)
dp
# Out:
#          price(Lacs)
# 2           ₹80 Lacs
# 5           ₹60 Lacs
# 8           ₹65 Lacs
# 11          ₹45 Lacs
# 17          ₹80 Lacs
# 20          ₹45 Lacs
# 23        ₹82.5 Lacs
# 26          ₹79 Lacs
# 29          ₹78 Lacs
# 32          ₹65 Lacs
# 35          ₹60 Lacs
# 38          ₹75 Lacs
# 40  ₹2.01 Lacs/Month
# 44          ₹80 Lacs
# 47          ₹85 Lacs
# 50          ₹35 Lacs
# 56          ₹80 Lacs
# 59          ₹85 Lacs
# 62          ₹57 Lacs
# 65          ₹60 Lacs
# 68          ₹55 Lacs
# 71          ₹85 Lacs

# %%
db=db.loc[db['BHK'].str.contains('BHK')]
db
# Out:
#       BHK
# 0   2 BHK
# 1   1 BHK
# 2   1 BHK
# 3   1 BHK
# 4   3 BHK
# 5   2 BHK
# 6   1 BHK
# 7   2 BHK
# 8   1 BHK
# 9   1 BHK
# 10  1 BHK
# 11  2 BHK
# 12  4 BHK
# 13  2 BHK
# 14  1 BHK
# 15  1 BHK
# 16  2 BHK
# 17  1 BHK
# 18  3 BHK
# 19  1 BHK
# 20  1 BHK
# 21  1 BHK
# 22  2 BHK
# 23  2 BHK

# %%
ds['Sqrft_details'] = ds['Sqrft_details'].str.replace(r'\D', '')
ds['Sqrft_details']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\819670684.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ds['Sqrft_details'] = ds['Sqrft_details'].str.replace(r'\D', '')
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\819670684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['Sqrft_details'] = ds['Sqrft_details'].str.replace(r'\D', '')
# 0      780
# 3      600
# 6      600
# 9      620
# 12    1400
# 15     730
# 18     391
# 21     660
# 24    1037
# 27     619
# 30     520
# 33     530
# 36     700
# 39    2000
# 42     950
# 45     597
# 48     350
# 51     810
# 54     600
# 57     885
# 60     725
# 63     550
# 66     553
# 69     740
# 72    1100
# ...

# %%
ds['Sqrft_details'] = ds['Sqrft_details'].str.replace(r'\D', '')
ds['Sqrft_details']
ds1=pd.DataFrame(ds['Sqrft_details'])
ds1=ds1.reset_index(drop=True)
ds1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\2874170168.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ds['Sqrft_details'] = ds['Sqrft_details'].str.replace(r'\D', '')
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\2874170168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['Sqrft_details'] = ds['Sqrft_details'].str.replace(r'\D', '')
#    Sqrft_details
# 0            780
# 1            600
# 2            600
# 3            620
# 4           1400
# 5            730
# 6            391
# 7            660
# 8           1037
# 9            619
# 10           520
# 11           530
# 12           700
# 13          2000
# 14           950
# 15           597
# ...

# %%
db['BHK'] = db['BHK'].str.replace(r'\D', '')
db
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\1958198137.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   db['BHK'] = db['BHK'].str.replace(r'\D', '')
#    BHK
# 0    2
# 1    1
# 2    1
# 3    1
# 4    3
# 5    2
# 6    1
# 7    2
# 8    1
# 9    1
# 10   1
# 11   2
# 12   4
# 13   2
# 14   1
# 15   1
# 16   2
# 17   1
# 18   3
# 19   1
# 20   1
# 21   1
# 22   2
# 23   2

# %%
dp1=dp.reset_index(drop=True)
dp1
# Out:
#          price(Lacs)
# 0           ₹80 Lacs
# 1           ₹60 Lacs
# 2           ₹65 Lacs
# 3           ₹45 Lacs
# 4           ₹80 Lacs
# 5           ₹45 Lacs
# 6         ₹82.5 Lacs
# 7           ₹79 Lacs
# 8           ₹78 Lacs
# 9           ₹65 Lacs
# 10          ₹60 Lacs
# 11          ₹75 Lacs
# 12  ₹2.01 Lacs/Month
# 13          ₹80 Lacs
# 14          ₹85 Lacs
# 15          ₹35 Lacs
# 16          ₹80 Lacs
# 17          ₹85 Lacs
# 18          ₹57 Lacs
# 19          ₹60 Lacs
# 20          ₹55 Lacs
# 21          ₹85 Lacs

# %%
dp1["price(Lacs)"]=dp1["price(Lacs)"].str.replace("Lacs","")
dp1["price(Lacs)"]=dp1["price(Lacs)"].str.replace("₹","")
dp1["price(Lacs)"]=dp1["price(Lacs)"].str.replace("/Month","")
dp1["price(Lacs)"]


#df1['Avg_Annual'] = df1['Avg_Annual'].str.replace(',', '')
# Out:
# 0       80
# 1       60
# 2       65
# 3       45
# 4       80
# 5       45
# 6     82.5
# 7       79
# 8       78
# 9       65
# 10      60
# 11      75
# 12    2.01
# 13      80
# 14      85
# 15      35
# 16      80
# 17      85
# 18      57
# 19      60
# 20      55
# 21      85
# Name: price(Lacs), dtype: object

# %%
dp1=pd.DataFrame(dp1["price(Lacs)"])
dp1
# Out:
#    price(Lacs)
# 0          80
# 1          60
# 2          65
# 3          45
# 4          80
# 5          45
# 6        82.5
# 7          79
# 8          78
# 9          65
# 10         60
# 11         75
# 12       2.01
# 13         80
# 14         85
# 15         35
# 16         80
# 17         85
# 18         57
# 19         60
# 20         55
# 21         85

# %%
dfinal_nobroker=pd.concat([ds1,dp1,db],axis=1)
dfinal_nobroker
# Out:
#    Sqrft_details price(Lacs)  BHK
# 0            780         80     2
# 1            600         60     1
# 2            600         65     1
# 3            620         45     1
# 4           1400         80     3
# 5            730         45     2
# 6            391       82.5     1
# 7            660         79     2
# 8           1037         78     1
# 9            619         65     1
# 10           520         60     1
# 11           530         75     2
# 12           700       2.01     4
# 13          2000         80     2
# 14           950         85     1
# 15           597         35     1
# 16           350         80     2
# 17           810         85     1
# 18           600         57     3
# 19           885         60     1
# 20           725         55     1
# 21           550         85     1
# 22           553         NaN    2
# 23           740         NaN    2
# 24          1100         NaN  NaN

# %% [markdown]
# # EDA

# %%
dfinal_nobroker=dfinal_nobroker.fillna(0)
dfinal_nobroker
# Out:
#    Sqrft_details price(Lacs) BHK
# 0            780         80    2
# 1            600         60    1
# 2            600         65    1
# 3            620         45    1
# 4           1400         80    3
# 5            730         45    2
# 6            391       82.5    1
# 7            660         79    2
# 8           1037         78    1
# 9            619         65    1
# 10           520         60    1
# 11           530         75    2
# 12           700       2.01    4
# 13          2000         80    2
# 14           950         85    1
# 15           597         35    1
# 16           350         80    2
# 17           810         85    1
# 18           600         57    3
# 19           885         60    1
# 20           725         55    1
# 21           550         85    1
# 22           553           0   2
# 23           740           0   2
# 24          1100           0   0

# %%
dfinal_nobroker=dfinal_nobroker.astype(float)

# %%
import seaborn as sns

# %%
sns.boxplot(y=dfinal_nobroker["price(Lacs)"],data=dfinal_nobroker)
# Out:
# <AxesSubplot:ylabel='price(Lacs)'>

# %%
def remove_outlier(dp):
                for i in dp.columns:
                    q1 = dp[i].quantile(0.25)
                    q3 = dp[i].quantile(0.75)
                    iqr = q3-q1 #Interquartile range
                    upper_limit = q3+1.5*iqr #acceptable range
                    lower_limit = q3-1.5*iqr
                    if ((dp[i].dtype=='float64')| (dp[i].dtype=='int64')):
                        dp[i][dp[i]>=upper_limit]=upper_limit
                        dp[i][dp[i]<=lower_limit]=lower_limit
                    else:
                        dp[i]=dp[i]
                return (dp)
remove_outlier(dfinal_nobroker)
# Out:
#     Sqrft_details  price(Lacs)  BHK
# 0           780.0         80.0  2.0
# 1           600.0         60.0  1.0
# 2           600.0         65.0  1.0
# 3           620.0         45.0  1.0
# 4          1129.5         80.0  3.0
# 5           730.0         45.0  2.0
# 6           490.5         82.5  1.0
# 7           660.0         79.0  2.0
# 8          1037.0         78.0  1.0
# 9           619.0         65.0  1.0
# 10          520.0         60.0  1.0
# 11          530.0         75.0  2.0
# 12          700.0         27.5  3.5
# 13         1129.5         80.0  2.0
# 14          950.0         85.0  1.0
# 15          597.0         35.0  1.0
# 16          490.5         80.0  2.0
# 17          810.0         85.0  1.0
# 18          600.0         57.0  3.0
# 19          885.0         60.0  1.0
# 20          725.0         55.0  1.0
# 21          550.0         85.0  1.0
# 22          553.0         27.5  2.0
# 23          740.0         27.5  2.0
# 24         1100.0         27.5  0.5

# %%
dfinal_nobroker.describe()
# Out:
#        Sqrft_details  price(Lacs)        BHK
# count       25.00000    25.000000  25.000000
# mean       725.84000    61.860000   1.560000
# std        203.35994    20.604166   0.781558
# min        490.50000    27.500000   0.500000
# 25%        597.00000    45.000000   1.000000
# 50%        660.00000    65.000000   1.000000
# 75%        810.00000    80.000000   2.000000
# max       1129.50000    85.000000   3.500000

# %%
dfinal_nobroker.corr()
# Out:
#                Sqrft_details  price(Lacs)       BHK
# Sqrft_details       1.000000     0.096987  0.028900
# price(Lacs)         0.096987     1.000000 -0.111364
# BHK                 0.028900    -0.111364  1.000000

# %%
e=pd.read_csv(r"C:\Users\User\Documents\all\realestate1.csv")
e
# Out:
#     Unnamed: 0  Sqrft_details  BHK price(lacs)
# 0            0            400    1         low
# 1            1            444   11        high
# 2            2            460    1        high
# 3            3            732    1        high
# 4            4            759    1        high
# 5            5            410    1         low
# 6            6            452    1         low
# 7            7            410    1         low
# 8            8            640    1         low
# 9            9            255    1         low
# 10          10           1200    2        high
# 11          11            340    1        high
# 12          12            680    2         low
# 13          13            440    1        high
# 14          14            500    1        high
# 15          15            808    2        high
# 16          16            982    2         low
# 17          17            784    2         low
# 18          18            530    1         low
# ...

# %%
dfinal_nobroker["price(Lacs)"]=pd.cut(dfinal_nobroker["price(Lacs)"],bins=[26,35,45,85],labels=["low","medium","high"])
dfinal_nobroker["price(Lacs)"]
# Out:
# 0       high
# 1       high
# 2       high
# 3     medium
# 4       high
# 5     medium
# 6       high
# 7       high
# 8       high
# 9       high
# 10      high
# 11      high
# 12       low
# 13      high
# 14      high
# 15       low
# 16      high
# 17      high
# 18      high
# 19      high
# 20      high
# 21      high
# 22       low
# 23       low
# 24       low
# Name: price(Lacs), dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %%
dfinal_nobroker
# Out:
#     Sqrft_details price(Lacs)  BHK
# 0           780.0        high  2.0
# 1           600.0        high  1.0
# 2           600.0        high  1.0
# 3           620.0      medium  1.0
# 4          1129.5        high  3.0
# 5           730.0      medium  2.0
# 6           490.5        high  1.0
# 7           660.0        high  2.0
# 8          1037.0        high  1.0
# 9           619.0        high  1.0
# 10          520.0        high  1.0
# 11          530.0        high  2.0
# 12          700.0         low  3.5
# 13         1129.5        high  2.0
# 14          950.0        high  1.0
# 15          597.0         low  1.0
# 16          490.5        high  2.0
# 17          810.0        high  1.0
# 18          600.0        high  3.0
# 19          885.0        high  1.0
# 20          725.0        high  1.0
# 21          550.0        high  1.0
# 22          553.0         low  2.0
# 23          740.0         low  2.0
# 24         1100.0         low  0.5

# %%
e=e.rename({"price(lacs)":"price(Lacs)"},axis=1)
e
# Out:
#     Unnamed: 0  Sqrft_details  BHK price(Lacs)
# 0            0            400    1         low
# 1            1            444   11        high
# 2            2            460    1        high
# 3            3            732    1        high
# 4            4            759    1        high
# 5            5            410    1         low
# 6            6            452    1         low
# 7            7            410    1         low
# 8            8            640    1         low
# 9            9            255    1         low
# 10          10           1200    2        high
# 11          11            340    1        high
# 12          12            680    2         low
# 13          13            440    1        high
# 14          14            500    1        high
# 15          15            808    2        high
# 16          16            982    2         low
# 17          17            784    2         low
# 18          18            530    1         low
# ...

# %%
final_data=pd.concat([e,dfinal_nobroker],axis=0)
final_data=final_data.reset_index(drop=True)
final_data
# Out:
#     Unnamed: 0  Sqrft_details   BHK price(Lacs)
# 0          0.0          400.0   1.0         low
# 1          1.0          444.0  11.0        high
# 2          2.0          460.0   1.0        high
# 3          3.0          732.0   1.0        high
# 4          4.0          759.0   1.0        high
# ..         ...            ...   ...         ...
# 60         NaN          725.0   1.0        high
# 61         NaN          550.0   1.0        high
# 62         NaN          553.0   2.0         low
# 63         NaN          740.0   2.0         low
# 64         NaN         1100.0   0.5         low
#
# [65 rows x 4 columns]

# %%
final_data["BHK"]=final_data["BHK"].replace({11:1})
final_data["BHK"]
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
#      ...
# 60    1.0
# 61    1.0
# 62    2.0
# 63    2.0
# 64    0.5
# Name: BHK, Length: 65, dtype: float64

# %%
final_data=final_data.drop(["Unnamed: 0"],axis=1)
final_data
# Out:
#     Sqrft_details  BHK price(Lacs)
# 0           400.0  1.0         low
# 1           444.0  1.0        high
# 2           460.0  1.0        high
# 3           732.0  1.0        high
# 4           759.0  1.0        high
# ..            ...  ...         ...
# 60          725.0  1.0        high
# 61          550.0  1.0        high
# 62          553.0  2.0         low
# 63          740.0  2.0         low
# 64         1100.0  0.5         low
#
# [65 rows x 3 columns]

# %%
final_data.to_csv(r"C:\Users\User\Documents\all\final_scrap_Real_estate_data.csv")

# %% [markdown]
# # MODEL BUILDING

# %%
import pandas as pd # Data frame 
import numpy as np # Data Calculation 
from scipy import stats

############# Data Visualization ###############
import seaborn as sns  
import matplotlib.pyplot as plt 

#################### Model #####################
import statsmodels.api as sm # 
from statsmodels.stats import diagnostic as diag 
from sklearn.model_selection import train_test_split # data partition
# %matplotlib inline
import os

# %%
x=final_data.drop("price(Lacs)", axis= 1)
y=final_data["price(Lacs)"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(x,y,train_size=0.7,random_state=100)

train = pd.concat([X_train,y_train], axis=1)
train
# Out:
#     Sqrft_details  BHK price(Lacs)
# 61          550.0  1.0        high
# 44         1129.5  3.0        high
# 28          400.0  1.0        high
# 60          725.0  1.0        high
# 50          520.0  1.0        high
# 35          700.0  2.0        high
# 46          490.5  1.0        high
# 17          784.0  2.0         low
# 7           410.0  1.0         low
# 62          553.0  2.0         low
# 45          730.0  2.0      medium
# 38          740.0  2.0        high
# 37          351.0  1.0         low
# 19          600.0  1.0        high
# 13          440.0  1.0        high
# 1           444.0  1.0        high
# 31          590.0  1.0        high
# 4           759.0  1.0        high
# 27          480.0  1.0         low
# 55          597.0  1.0         low
# 22          750.0  2.0         low
# 29          500.0  1.0        high
# 9           255.0  1.0         low
# 16          982.0  2.0         low
# 43          620.0  1.0      medium
# 36          351.0  1.0         low
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 61 to 8
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sqrft_details  45 non-null     float64
#  1   BHK            45 non-null     float64
#  2   price(Lacs)    45 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 1.4+ KB

# %%
train["BHK"]=train["BHK"].replace(11,1)
train["BHK"]
# Out:
# 61    1.0
# 44    3.0
# 28    1.0
# 60    1.0
# 50    1.0
# 35    2.0
# 46    1.0
# 17    2.0
# 7     1.0
# 62    2.0
# 45    2.0
# 38    2.0
# 37    1.0
# 19    1.0
# 13    1.0
# 1     1.0
# 31    1.0
# 4     1.0
# 27    1.0
# 55    1.0
# 22    2.0
# 29    1.0
# 9     1.0
# 16    2.0
# 43    1.0
# 36    1.0
# 59    1.0
# 63    2.0
# 58    3.0
# 51    2.0
# 14    1.0
# 54    1.0
# 2     1.0
# 53    2.0
# 34    1.0
# 52    3.5
# 30    1.0
# 10    2.0
# 48    1.0
# 15    2.0
# 23    1.0
# 39    1.0
# 3     1.0
# 24    1.0
# 8     1.0
# Name: BHK, dtype: float64

# %%
sns.barplot(y="Sqrft_details",data=train)
# Out:
# <AxesSubplot:ylabel='Sqrft_details'>

# %%
sns.scatterplot(y="Sqrft_details",data=train,hue="price(Lacs)")
# Out:
# <AxesSubplot:ylabel='Sqrft_details'>

# %% [markdown]
# # avg_High_price_Sqft

# %%
avg_High_price_Sqft=final_data[final_data["price(Lacs)"]=="high"]

# %%
avg_High_price_Sqft.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\3667045324.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_High_price_Sqft.mean()
# Sqrft_details    660.473684
# BHK                1.342105
# dtype: float64

# %%
avg_low_price_Sqft=final_data[final_data["price(Lacs)"]=="low"]
avg_low_price_Sqft.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\735782007.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_low_price_Sqft.mean()
# Sqrft_details    563.88
# BHK                1.32
# dtype: float64

# %%
avg_medium_price_Sqft=final_data[final_data["price(Lacs)"]=="medium"]
avg_medium_price_Sqft.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\2240925971.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_medium_price_Sqft.mean()
# Sqrft_details    675.0
# BHK                1.5
# dtype: float64

# %% [markdown]
# # it seams, for high price(more than 45lacs) the mean is 660 only 100 more than low,it shows area of demand is really important with sqrft of house.

# %%
final_data["price(Lacs)"].value_counts()
# Out:
# high      38
# low       25
# medium     2
# Name: price(Lacs), dtype: int64

# %%
avg_low_price_Sqft.std()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\101840023.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_low_price_Sqft.std()
# Sqrft_details    200.236801
# BHK                0.643558
# dtype: float64

# %%
avg_High_price_Sqft.std()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\3519629220.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_High_price_Sqft.std()
# Sqrft_details    211.352049
# BHK                0.582461
# dtype: float64

# %%
avg_medium_price_Sqft.std()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13652\3821677061.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_medium_price_Sqft.std()
# Sqrft_details    77.781746
# BHK               0.707107
# dtype: float64

# %% [markdown]
# # std for high and low price are same.but medium has low number.so most houses rate 35 to 45  in lacs,this no"s have most reliability.

# %% [markdown]
# # NAive Bayes

# %%
train.info()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O 
import os
import matplotlib.pyplot as plt#visualization
from PIL import  Image
# %matplotlib inline
import pandas as pd
import seaborn as sns#visualization
import itertools
import warnings
warnings.filterwarnings("ignore")
import io
import plotly.offline as py#visualization
py.init_notebook_mode(connected=True)#visualization
import plotly.graph_objs as go#visualization
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Import Tree Classifier model
from sklearn import tree

dt = tree.DecisionTreeClassifier()  # by default it use Gini index for split
#Train the model using the training sets
dt.fit(X_train_1,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
import matplotlib.pyplot as plt

price(Lacs)= ['low',"medium", 'high']  # array
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (5,4), dpi=300)
tree.plot_tree(dt,
               feature_names = features, 
               class_names=price(Lacs),
               filled = True, # colour
              node_ids=True, # node number
              fontsize=2); # 
#fig.savefig('imagename.png')
# Out:
#   Input In [95]
#     price(Lacs)= ['low',"medium", 'high']  # array
#     ^
# SyntaxError: cannot assign to function call

# %%
train['Predicted']=dt.predict(X_train)
train.head()
# Out:
#     Sqrft_details  BHK price(Lacs) Predicted
# 61          550.0  1.0        high      high
# 44         1129.5  3.0        high       low
# 28          400.0  1.0        high      high
# 60          725.0  1.0        high      high
# 50          520.0  1.0        high      high

# %%
from sklearn.metrics import confusion_matrix  
matrix = confusion_matrix(train['Predicted'],train['price(Lacs)'])
print(matrix)
# Out:
# [[27 15]
#  [ 2  1]]

# %%
train_pred = dt.predict(X_train)
test_pred = dt.predict(X_test)
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print('Classification report for train data is : \n',
      classification_report(y_train, train_pred))
print('Classification report for test data is : \n',
      classification_report(y_test, test_pred))
# Out:
# Classification report for train data is :
#                precision    recall  f1-score   support
#
#         high       0.64      0.93      0.76        29
#          low       0.33      0.07      0.12        14
#       medium       0.00      0.00      0.00         2
#
#     accuracy                           0.62        45
#    macro avg       0.33      0.33      0.29        45
# weighted avg       0.52      0.62      0.53        45
#
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#         high       0.45      1.00      0.62         9
#          low       0.00      0.00      0.00        11
#
#     accuracy                           0.45        20
#    macro avg       0.23      0.50      0.31        20
# weighted avg       0.20      0.45      0.28        20

# %%
list()

# %%
accuracy=(((16+11)/28)*100)
accuracy
# Out:
# 96.42857142857143

# %%
test=pd.concat([X_test,y_test],axis=1)
test.head()
# Out:
#     Sqrft_details  BHK price(Lacs)
# 41          600.0  1.0        high
# 32          500.0  1.0         low
# 12          680.0  2.0         low
# 56          490.5  2.0        high
# 57          810.0  1.0        high

# %%
test['Predicted']=dt.predict(X_test)
test.head()
# Out:
#     Sqrft_details  BHK price(Lacs) Predicted
# 41          600.0  1.0        high      high
# 32          500.0  1.0         low      high
# 12          680.0  2.0         low      high
# 56          490.5  2.0        high      high
# 57          810.0  1.0        high      high

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(test['Predicted'],test['price(Lacs)'])
print(confusion_matrix)
# Out:
# [[6 9 0]
#  [2 2 0]
#  [1 0 0]]

# %%
accuracy=((8/12)*100)
accuracy
# Out:
# 66.66666666666666

# %% [markdown]
# # logistic

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
output=logreg.fit(X_train, y_train)

# %%
output.intercept_
# Out:
# array([ 0.70584244,  1.32601874, -2.03186117])

# %%
output.coef_
# Out:
# array([[ 0.00178285, -0.49495355],
#        [-0.00256545,  0.46549119],
#        [ 0.0007826 ,  0.02946235]])

# %%
output.n_features_in_
# Out:
# 2

# %%
output.feature_names_in_
# Out:
# array(['Sqrft_details', 'BHK'], dtype=object)

# %%
train=pd.concat([X_train,y_train],axis=1)
train.head()
train['Predicted']=output.predict(X_train)
train.head()
# Out:
#     Sqrft_details  BHK price(Lacs) Predicted
# 61          550.0  1.0        high      high
# 44         1129.5  3.0        high      high
# 28          400.0  1.0        high      high
# 60          725.0  1.0        high      high
# 50          520.0  1.0        high      high

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(train['Predicted'], train['price(Lacs)'])
matrix
# Out:
# array([[27,  9,  2],
#        [ 2,  5,  0],
#        [ 0,  0,  0]], dtype=int64)

# %%
Accuracy_Train=((27+5)/(27+5+9+2+2)*100)
print(Accuracy_Train)
# Out:
# 71.11111111111111

# %%
train_pred = dt.predict(X_train)
test_pred = dt.predict(X_test)
from sklearn.metrics import confusion_matrix, classification_report

# %%
print('Classification report for test data is : \n',
      classification_report(y_test, test_pred))
# Out:
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#         high       0.40      0.67      0.50         9
#          low       0.50      0.18      0.27        11
#       medium       0.00      0.00      0.00         0
#
#     accuracy                           0.40        20
#    macro avg       0.30      0.28      0.26        20
# weighted avg       0.45      0.40      0.37        20

# %% [markdown]
# # treating imbalance of Data  and scaling

# %%
train["price(Lacs)"]=train["price(Lacs)"].replace("medium","low")

# %%
final_data# performing preprocessing part 
from sklearn.preprocessing import StandardScaler 

sc = StandardScaler() # mean 0 & std=1
  
X_train_1 = sc.fit_transform(X_train)

# %%
X_train_1
# Out:
# array([[-0.45016097, -0.63869093],
#        [ 2.24136091,  2.46845413],
#        [-1.14684481, -0.63869093],
#        [ 0.36263684, -0.63869093],
#        [-0.58949774, -0.63869093],
#        [ 0.24652287,  0.9148816 ],
#        [-0.72651222, -0.63869093],
#        [ 0.63666581,  0.9148816 ],
#        [-1.10039922, -0.63869093],
#        [-0.43622729,  0.9148816 ],
#        [ 0.38585963,  0.9148816 ],
#        [ 0.43230522,  0.9148816 ],
#        [-1.37442819, -0.63869093],
#        [-0.21793302, -0.63869093],
#        [-0.96106245, -0.63869093],
#        [-0.94248421, -0.63869093],
#        [-0.26437861, -0.63869093],
#        [ 0.52055184, -0.63869093],
#        [-0.77528009, -0.63869093],
#        [-0.2318667 , -0.63869093],
#        [ 0.47875081,  0.9148816 ],
#        [-0.68238892, -0.63869093],
#        [-1.82030585, -0.63869093],
#        [ 1.55628848,  0.9148816 ],
#        [-0.12504185, -0.63869093],
#        [-1.37442819, -0.63869093],
#        [ 1.10576626, -0.63869093],
# ...

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier


# by default 100 tree will be form 
Model = RandomForestClassifier(n_estimators=10, # make 15 tress
                               criterion="gini",
                               max_depth=3,  # each tree will have 4 branches
                               min_samples_split=5,# each tree will have parent node
                               min_samples_leaf=75,# each tree will have Child node
                               max_features="sqrt")# n_estimators means number tree we want  

Model.fit(X_train_1,y_train)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_leaf=75, min_samples_split=5,
#                        n_estimators=10)

# %%
# !pip install pydot

# %%
train=pd.concat([X_train,y_train],axis=1)
train.head()
# Out:
#     Sqrft_details  BHK price(Lacs)
# 61          550.0  1.0        high
# 44         1129.5  3.0        high
# 28          400.0  1.0        high
# 60          725.0  1.0        high
# 50          520.0  1.0        high

# %%
train['Predicted']=Model.predict(X_train)
train.head()
# Out:
#     Sqrft_details  BHK price(Lacs) Predicted
# 61          550.0  1.0        high      high
# 44         1129.5  3.0        high      high
# 28          400.0  1.0        high      high
# 60          725.0  1.0        high      high
# 50          520.0  1.0        high      high

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(train['price(Lacs)'], train['Predicted'])
print(confusion_matrix)
# Out:
# [[29  0]
#  [16  0]]

# %%
Accuracy_test=((29)/(16+29)*100)
Accuracy_test
# Out:
# 64.44444444444444

# %%
dff=dff.astype(np.int)
dff

# %%
dff.corr()

# %%
dff["Sqrft_details"]=dff["Sqrft_details"]**0.25
dff["Sqrft_details"]

# %%
dff.corr()

# %% [markdown]
# # Beautiful soup 4 and requests

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
Beautiful soup 4 and requests

# %%
import sys
import time
from bs4 import Beautifulsoup
import requests

# %%
try:
    page=requests.get('https://www.cricbuzz.com/')
except Exeption as e :
    error_type,error_obj,error_info
